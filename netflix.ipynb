# %%
import pandas as pd

# %%
df = pd.read_csv('titles.csv')

# %%
df
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
df.shape
# Out:
# (5850, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %%
df.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
df.isnull().any()
# Out:
# id                      False
# title                   False
# type                    False
# description              True
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes               True
# tmdb_popularity          True
# tmdb_score               True
# dtype: bool

# %%
df.dropna(subset=['title'])
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
# Duplicates 
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
df = df.drop_duplicates()

# %%
# Nulls
df.isnull().any()
# Out:
# id                      False
# title                    True
# type                    False
# description              True
# release_year            False
# age_certification        True
# runtime                 False
# genres                  False
# production_countries    False
# seasons                  True
# imdb_id                  True
# imdb_score               True
# imdb_votes               True
# tmdb_popularity          True
# tmdb_score               True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
df[df['title'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
df = df.drop(1704)

# %%
df.shape
# Out:
# (5849, 15)

# %%
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
# Remove unnecessary characters

# %%
df['genres'] = df['genres'].str.replace('\'', '', regex=True)

# %%
df['genres'] = df['genres'].str.replace('\[', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# C:\Users\Charles\AppData\Local\Temp\ipykernel_13136\95931325.py:1: SyntaxWarning: invalid escape sequence '\['
#   df['genres'] = df['genres'].str.replace('\[', '', regex=True)

# %%
df['genres'] = df['genres'].str.replace('\]', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\]'
# <>:1: SyntaxWarning: invalid escape sequence '\]'
# C:\Users\Charles\AppData\Local\Temp\ipykernel_13136\1267350270.py:1: SyntaxWarning: invalid escape sequence '\]'
#   df['genres'] = df['genres'].str.replace('\]', '', regex=True)

# %%
df['genres']
# Out:
# 0                           documentation
# 1                            drama, crime
# 2       drama, action, thriller, european
# 3                 fantasy, action, comedy
# 4                             war, action
#                       ...
# 5845                       romance, drama
# 5846                                drama
# 5847                               comedy
# 5848
# 5849            family, animation, comedy
# Name: genres, Length: 5850, dtype: object

# %%
df['production_countries'] = df['production_countries'].str.replace('\'', '', regex=True)

# %%
df['production_countries'] = df['production_countries'].str.replace('\[', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\['
# <>:1: SyntaxWarning: invalid escape sequence '\['
# C:\Users\Charles\AppData\Local\Temp\ipykernel_13136\1773360954.py:1: SyntaxWarning: invalid escape sequence '\['
#   df['production_countries'] = df['production_countries'].str.replace('\[', '', regex=True)

# %%
df['production_countries'] = df['production_countries'].str.replace('\]', '', regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\]'
# <>:1: SyntaxWarning: invalid escape sequence '\]'
# C:\Users\Charles\AppData\Local\Temp\ipykernel_13136\3181854388.py:1: SyntaxWarning: invalid escape sequence '\]'
#   df['production_countries'] = df['production_countries'].str.replace('\]', '', regex=True)

# %%
df['production_countries']
# Out:
# 0           US
# 1           US
# 2           US
# 3           GB
# 4       GB, US
#          ...
# 5845        NG
# 5846
# 5847        CO
# 5848        US
# 5849
# Name: production_countries, Length: 5850, dtype: object

# %%
df['production_countries']
# Out:
# 0           US
# 1           US
# 2           US
# 3           GB
# 4       GB, US
#          ...
# 5845        NG
# 5846
# 5847        CO
# 5848        US
# 5849
# Name: production_countries, Length: 5850, dtype: object

# %%
# Convert float seasons to int

# %%
df['seasons'] = df['seasons'].astype(pd.Int32Dtype())

# %%
df['imdb_votes'] = df['imdb_votes'].astype(pd.Int32Dtype())

# %%
df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                             genres  \
# 0             TV-MA       51                      documentation
# 1                 R      114                       drama, crime
# ...

# %%
# Round out tmdb score to provide equal comparison

# %%
df['tmdb_popularity'] = df['tmdb_popularity'].round(2)

# %%
df['tmdb_score'] = df['tmdb_score'].round(1)

# %%
df.to_csv('titles_final.csv', index=False)

# %%
# Credits.csv

# %%
df2 = pd.read_csv('credits.csv')

# %%
df2
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77800     736339  tm1059008    Adelaida Buscato                María Paz
# 77801     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77802     373198  tm1059008         Inés Prieto                    Fanny
# 77803     378132  tm1059008        Isabel Gaona                   Cacica
# 77804    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
df2.shape
# Out:
# (77805, 5)

# %%
df2.info
# Out:
# <bound method DataFrame.info of        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# ...

# %%
df2.dtypes
# Out:
# person_id     int64
# id           object
# name         object
# character    object
# role         object
# dtype: object

# %%
df2.isnull().any()
# Out:
# person_id    False
# id           False
# name         False
# character     True
# role         False
# dtype: bool

# %%
# Duplicates 
df2[df2.duplicated()]
# Out:
#        person_id        id             name                      character  \
# 10          3308   tm84618  Martin Scorsese  Passenger Watching Silhouette
# 4781        1941   ts17156    Jason Bateman                  Michael Bluth
# 18472      63996  tm155291       Alia Bhatt                 Veera Tripathi
# 34533       1738    tm1883      Emily Blunt         Zoe Huntington (voice)
#
#         role
# 10     ACTOR
# 4781   ACTOR
# 18472  ACTOR
# 34533  ACTOR

# %%
df2 = df2.drop_duplicates()

# %%
df2.to_csv('credits_final.csv', index=False)
